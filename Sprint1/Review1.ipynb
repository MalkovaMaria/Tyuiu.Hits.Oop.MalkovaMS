# %%
public class Product
{
    private string name;
    private decimal price;
    private int quantity;
    protected string category;
    internal string description;

    public string Name
    {
        get { return name; }
        set { name = value; }
    }

    public decimal Price
    {
        get { return price; }
        set { price = value; }
    }

    public int Quantity
    {
        get { return quantity; }
        set { quantity = value; }
    }

    public string Category
    {
        get { return category; }
        set { category = value; }
    }

    public string Description
    {
        get { return description; }
        set { description = value; }
    }

    public Product(string name, decimal price, int quantity, string category, string description)
    {
        this.name = name;
        this.price = price;
        this.quantity = quantity;
        this.category = category;
        this.description = description;
    }

    public decimal GetTotalPrice()
    {
        return price * quantity;
    }

    public void UpdateQuantity(int amount)
    {
        quantity = amount;
        Console.WriteLine($"Количество товара {name} обновлено: {quantity} шт.");
    }

    public string GetProductInfo()
    {
        return $"Товар: {name}, Категория: {category}, Цена: {price} руб., Кол-во: {quantity}, Описание: {description}";
    }
}


public class Seller
{
    private string name;
    private string employeeId;
    protected decimal salary;
    internal string contactInfo;

    private List<Product> products = new List<Product>();

    public List<Product> Products 
    { 
        get { return products; } 
    }

    public string Name
    {
        get { return name; }
        set { name = value; }
    }

    public string EmployeeId
    {
        get { return employeeId; }
        set { employeeId = value; }
    }

    public decimal Salary
    {
        get { return salary; }
        set { salary = value; }
    }

    public string ContactInfo
    {
        get { return contactInfo; }
        set { contactInfo = value; }
    }

    public Seller(string name, string employeeId, decimal salary, string contactInfo)
    {
        this.name = name;
        this.employeeId = employeeId;
        this.salary = salary;
        this.contactInfo = contactInfo;
    }

    public void AddProduct(Product product)
    {
        products.Add(product);
        Console.WriteLine($"Продавец {name} добавил товар '{product.Name}'");
    }

    public void SellProduct(Product product, int quantity)
    {
        if (product.Quantity >= quantity)
        {
            Console.WriteLine($"Продано {quantity} шт. товара '{product.Name}'");
            product.UpdateQuantity(product.Quantity - quantity);
        }
        else
        {
            Console.WriteLine($"Недостаточно товара '{product.Name}' на складе.");
        }
    }

    public string GetSellerInfo()
    {
        return $"Продавец: {name}, ID: {employeeId}, Зарплата: {salary} руб., Контакт: {contactInfo}";
    }
}

public class Store
{
    private string storeName;
    private string location;
    public string storeHours;

    private List<Seller> sellers = new List<Seller>();

    public string StoreName
    {
        get { return storeName; }
        set { storeName = value; }
    }

    public string Location
    {
        get { return location; }
        set { location = value; }
    }

    public string StoreHours
    {
        get { return storeHours; }
        set { storeHours = value; }
    }

    public Store(string storeName, string location, string storeHours)
    {
        this.storeName = storeName;
        this.location = location;
        this.storeHours = storeHours;
    }

    public void AddSeller(Seller seller)
    {
        sellers.Add(seller);
        Console.WriteLine($"В магазин '{storeName}' добавлен продавец {seller.Name}");
    }

    public void ListProducts()
    {
        Console.WriteLine($"\n--- Товары в магазине '{storeName}' ---");
        bool found = false;
        foreach (var seller in sellers)
        {
            foreach (var product in seller.Products)
            {
                Console.WriteLine($"- {product.GetProductInfo()}");
                found = true;
            }
        }

        if (!found)
        {
            Console.WriteLine("В магазине пока нет товаров.");
        }
    }

    public string GetStoreInfo()
    {
        return $"Магазин: {storeName}, Адрес: {location}, Часы работы: {storeHours}";
    }
}

Product shampoo = new Product("Шампунь Чистая Линия", 350, 10, "Косметическая продукция", "Шампунь для тонких волос");
Seller vika = new Seller("Виктория", "A-067", 70000, "vukisha@mail.ru");
Store shop = new Store("Бьюти Маркет", "ул. Мельникайте, д. 81", "10:00-21:00");

Console.WriteLine("=== МАГАЗИН ===\n");

Console.WriteLine($"Название: {shop.StoreName}");
Console.WriteLine($"Часы работы: {shop.StoreHours}");
Console.WriteLine($"Адрес: {shop.Location}");

Console.WriteLine("\n--- Работа магазина ---");
shop.AddSeller(vika);
vika.AddProduct(shampoo);

Console.WriteLine("\n--- Информация о продавцах ---");
Console.WriteLine(vika.GetSellerInfo());

shop.ListProducts();

Console.WriteLine("\n--- Операции с товаром ---");
shampoo.UpdateQuantity(15);
vika.SellProduct(shampoo, 3);

Console.WriteLine($"\nИтоговая стоимость остатка товара на складе: {shampoo.GetTotalPrice()} руб.");
# Out:
# === МАГАЗИН ===
#
# Название: Бьюти Маркет
# Часы работы: 10:00-21:00
# Адрес: ул. Мельникайте, д. 81
#
# --- Работа магазина ---
# В магазин 'Бьюти Маркет' добавлен продавец Виктория
# Продавец Виктория добавил товар 'Шампунь Чистая Линия'
#
# --- Информация о продавцах ---
# Продавец: Виктория, ID: A-067, Зарплата: 70000 руб., Контакт: vukisha@mail.ru
#
# --- Товары в магазине 'Бьюти Маркет' ---
# - Товар: Шампунь Чистая Линия, Категория: Косметическая продукция, Цена: 350 руб., Кол-во: 10, Описание: Шампунь для тонких волос
#
# --- Операции с товаром ---
# Количество товара Шампунь Чистая Линия обновлено: 15 шт.
# Продано 3 шт. товара 'Шампунь Чистая Линия'
# Количество товара Шампунь Чистая Линия обновлено: 12 шт.
#
# Итоговая стоимость остатка товара на складе: 4200 руб.
