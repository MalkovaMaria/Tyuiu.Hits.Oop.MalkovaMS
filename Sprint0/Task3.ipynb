// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания 16

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// Описание задачи:
// Создать базовый класс PaymentMethod в C#, который будет представлять
// различные способы оплаты. На основе этого класса разработать 2-3 производных
// класса, демонстрирующих принципы наследования и полиморфизма. В каждом из
// классов должны быть реализованы новые атрибуты и методы, а также
// переопределены некоторые методы базового класса для демонстрации
// полиморфизма.
// Требования к базовому классу PaymentMethod:
// • Атрибуты: ID способа оплаты (PaymentMethodId), Название способа оплаты
// (MethodName), Минимальная сумма (MinAmount).
// • Методы:
// o ProcessPayment(decimal amount): метод для обработки платежа
// указанной суммы.
// o CheckMinimumAmount(decimal amount): метод для проверки
// минимальной суммы платежа.
// o GetPaymentDetails(): метод для получения деталей способа оплаты.
// Требования к производным классам:
// 1. ОнлайнОплата (OnlinePayment): Должен содержать дополнительные
// атрибуты,
// такие
// как
// URL платежной системы (PaymentUrl).
// Метод ProcessPayment() должен быть переопределен для включения URL
// платежной системы в процесс оплаты.
// 2. БанковскийПеревод (BankTransfer): Должен содержать дополнительные
// атрибуты,
// такие
// как
// Банковские
// данные
// (BankData).
// Метод CheckMinimumAmount() должен быть переопределен для проверки
// минимальной суммы платежа с учетом банковских комиссий.
// 3. Наличные (CashPayment) (если требуется третий класс): Должен содержать
// дополнительные атрибуты, такие как Место выдачи наличных
// (CashPickupPoint). Метод GetPaymentDetails() должен быть переопределен
// для отображения места выдачи наличных.

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
class PaymentMethod
{
    public int PaymentMethodId {get; set;}
    public string MethodName {get; set;}
    public decimal MinAmount {get; set;}

    public virtual void ProcessPayment(decimal amount)
    {
        if (CheckMinimumAmount(amount))
    {
        Console.WriteLine($"Платеж через {MethodName} в размере {amount} руб. обработан");
    }
    else
    {
        Console.WriteLine($"Платеж методом '{MethodName}' в размере {amount} руб. отклонен. Недостаточная сумма");
    }
    }

    public virtual bool CheckMinimumAmount(decimal amount)
    {
        if (amount >= MinAmount)
        {
            Console.WriteLine("Минимальная сумма платежа набрана");
            return true;
        }
        else
        {
            Console.WriteLine($"Минимальная сумма платежа не набрана");
            return false;
        }
    }

    public virtual void GetPaymentDetails()
    {
        Console.WriteLine($"Детали платежа: ID: {PaymentMethodId}, Способ оплаты: {MethodName}, Минимальная сумма: {MinAmount} руб.");
    }
}

class OnlinePayment : PaymentMethod
{
    public string PaymentUrl {get; set;}

    public OnlinePayment(string paymentURL)
    {
        PaymentUrl = paymentURL;
        this.PaymentMethodId = 1;
        this.MethodName = "Онлайн оплата";
        this.MinAmount = 10;
    }

    public override void ProcessPayment(decimal amount)
    {
        base.ProcessPayment(amount); 
        if (amount >= MinAmount) 
        {
            Console.WriteLine($"Оплата проведена по URL: {PaymentUrl}");
        }
    }
}

class BankTransfer : PaymentMethod
{
    public decimal BankData {get; set;}

    public BankTransfer(decimal bankData)
    {
        BankData = bankData;
        this.PaymentMethodId = 2;
        this.MethodName = "Банковский перевод";
        this.MinAmount = 50;
    }

    public override bool CheckMinimumAmount(decimal amount)
    {
        decimal commission = amount / 100 * BankData;
        decimal amountAfterCommission = amount - commission;

        if (amountAfterCommission >= MinAmount)
            {
                Console.WriteLine($"Сумма достаточна. Комиссия составит {commission} руб.");
                return true;
            }
        else
            {
                Console.WriteLine($"Недостаточно средств. После комиссии {commission} руб. останется {amountAfterCommission} руб.");
                return false;
            }
    }
}

class CashPayment : PaymentMethod
{
    public string CashPickupPoint {get; set;}

    public CashPayment(string cashPuckupPoint)
    {
        CashPickupPoint = cashPuckupPoint;
        this.PaymentMethodId = 3;
        this.MethodName = "Наличные";
        this.MinAmount = 100;

    }

    public override void GetPaymentDetails()
    {
        Console.WriteLine($"Детали оплаты: ID: {PaymentMethodId}, Название способа оплаты: {MethodName}, Минимальная сумма: {MinAmount}, Место выдачи наличных: {CashPickupPoint}");
    }
}

string URL = "https://api.bank.ru/online/transfer";
decimal summ = 56;

OnlinePayment onlcash = new OnlinePayment(URL);
onlcash.GetPaymentDetails();
onlcash.ProcessPayment(summ);

Console.WriteLine();

BankTransfer bankcash = new BankTransfer(10);
bankcash.GetPaymentDetails();
bankcash.ProcessPayment(summ);

Console.WriteLine();

CashPayment cash = new CashPayment("Газпромбанк");
cash.GetPaymentDetails();
cash.ProcessPayment(summ);
// Out:
// Детали платежа: ID: 1, Способ оплаты: Онлайн оплата, Минимальная сумма: 10 руб.
// Минимальная сумма платежа набрана
// Платеж через Онлайн оплата в размере 56 руб. обработан
// Оплата проведена по URL: https://api.bank.ru/online/transfer
//
// Детали платежа: ID: 2, Способ оплаты: Банковский перевод, Минимальная сумма: 50 руб.
// Сумма достаточна. Комиссия составит 5.60 руб.
// Платеж через Банковский перевод в размере 56 руб. обработан
//
// Детали оплаты: ID: 3, Название способа оплаты: Наличные, Минимальная сумма: 100, Место выдачи наличных: Газпромбанк
// Минимальная сумма платежа не набрана
// Платеж методом 'Наличные' в размере 56 руб. отклонен. Недостаточная сумма
